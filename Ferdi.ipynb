# %%
import pandas as pd
df = pd.read_excel('Measurments.xlsx')
from math import sin, cos, radians
import matplotlib.pyplot as plt

current_x = 500
current_y = 600
Fix_coords = [(current_x, current_y)]
#Der erste Fixpunkt aus der Liste FP0 ist fiktiv. Damit alle Werte Positiv bleiben wird er bei 500 , 600 gesetzt. 

Fixpoints = df[df['ID'].str.contains('FP')]
#Dieser DataFrame enthält jetzt nur die Fixpunkte. 

m = 0

while m < len(Fixpoints):
  current_x = current_x + ((Fixpoints['DISTANCE'][m]) * (cos(radians((Fixpoints['ANGLE'][m]) - 90))* -1))
  current_y = current_y + ((Fixpoints['DISTANCE'][m]) * (sin(radians((Fixpoints['ANGLE'][m]) - 90))* -1))
  Fix_coords.append((current_x, current_y))
  m = m + 1
#Hier werden die Polarkoordinaten in Kartesische-Koordinaten umgerechnet und in der Liste Fix_coords gespeichert.

plt.plot(*zip(*Fix_coords))
plt.show()
#hier werden schon mal die Fixpunke aufgeplottet.

Measurs = df[~df['ID'].str.contains('F')]
Measurepoints = Measurs.reset_index(drop=True)
#Hier will ich einen zweiten DataFrame erstellen der nun nur die Messpunkte enthält. Danach will ich den DataFrame auf 0 setzten,
#damit er nicht bei 11 beginnt. warum das nur über diesen merkwürdigen Umweg funktioniert weiß ich nicht.  

Point_coords = []
#in dieser Liste sollen gleich die errechneten Kartesischen-Koordinaten aus den Messpunkten errchnt werden. 
 
#print(Measurepoints)
#print(Fixpoints)
#print(Fix_coords)

#So... bis hier hin funktioniert alles. Jetzt kommt der Teil der nicht funktioniert im Gegensatz zu den Fixpunken die ja vortschreitend von einem zum nächsten gemessen werden,
#werden die Messpunkte von den unterschhiedlichen Fixpunken aus gemessen. Das habe ich versucht mit dieser whileSchleife zu lösen was wiegesagt nicht funktioniert. 
#Ich glaube es liegt irgendwie an dem Ticker. 
#An sich ist diese Lösung aber ohnehin sehr unelegat da man ja so wirklich nur diese eine Exeltabelle einlesen kann und nicht jede beliebige. Damit das komplett automatisch läuft
#müsste man wahrscheinlich die einzelnen Koordinaten-Paare in der Liste Fix_coords mit einer Nummerierung versehen, ich weiß aber nicht wie das geht.
#(vielleicht als Liste von Tupeln???)


q = 0
#nach dem Durchlauf wird hier angezeit das q = 11 ist. Ich denke daher das das Program einmal durch die 11 Blöcke hier läuft dann aber abbricht. 

while q < len(Measurepoints):
  if (Measurepoints['FROM_POINT'][q]) == (Fixpoints['FROM_POINT'][0]):
    next_x = (Fix_coords[0][0]) + ((Fixpoints['DISTANCE'][q]) * (cos(radians((Fixpoints['ANGLE'][q]) - 90))* -1))
    next_y = (Fix_coords[0][1]) + ((Fixpoints['DISTANCE'][q]) * (sin(radians((Fixpoints['ANGLE'][q]) - 90))* -1))
    Point_coords.append((next_x, next_y))
    q = q + 1
  elif (Measurepoints['FROM_POINT'][q]) == (Fixpoints['ID'][0]):
    next_x = (Fix_coords[1][0]) + ((Fixpoints['DISTANCE'][q]) * (cos(radians((Fixpoints['ANGLE'][q]) - 90))* -1))
    next_y = (Fix_coords[1][1]) + ((Fixpoints['DISTANCE'][q]) * (sin(radians((Fixpoints['ANGLE'][q]) - 90))* -1))
    Point_coords.append((next_x, next_y))
    q = q + 1
  elif (Measurepoints['FROM_POINT'][q]) == (Fixpoints['ID'][1]):
    next_x = (Fix_coords[2][0]) + ((Fixpoints['DISTANCE'][q]) * (cos(radians((Fixpoints['ANGLE'][q]) - 90))* -1))
    next_y = (Fix_coords[2][1]) + ((Fixpoints['DISTANCE'][q]) * (sin(radians((Fixpoints['ANGLE'][q]) - 90))* -1))
    Point_coords.append((next_x, next_y))
    q = q + 1
  elif (Measurepoints['FROM_POINT'][q]) == (Fixpoints['ID'][2]):
    next_x = (Fix_coords[3][0]) + ((Fixpoints['DISTANCE'][q]) * (cos(radians((Fixpoints['ANGLE'][q]) - 90))* -1))
    next_y = (Fix_coords[3][1]) + ((Fixpoints['DISTANCE'][q]) * (sin(radians((Fixpoints['ANGLE'][q]) - 90))* -1))
    Point_coords.append((next_x, next_y))
    q = q + 1
  elif (Measurepoints['FROM_POINT'][q]) == (Fixpoints['ID'][3]):
    next_x = (Fix_coords[4][0]) + ((Fixpoints['DISTANCE'][q]) * (cos(radians((Fixpoints['ANGLE'][q]) - 90))* -1))
    next_y = (Fix_coords[4][1]) + ((Fixpoints['DISTANCE'][q]) * (sin(radians((Fixpoints['ANGLE'][q]) - 90))* -1))
    Point_coords.append((next_x, next_y))
    q = q + 1
  elif (Measurepoints['FROM_POINT'][q]) == (Fixpoints['ID'][4]):
    next_x = (Fix_coords[5][0]) + ((Fixpoints['DISTANCE'][q]) * (cos(radians((Fixpoints['ANGLE'][q]) - 90))* -1))
    next_y = (Fix_coords[5][1]) + ((Fixpoints['DISTANCE'][q]) * (sin(radians((Fixpoints['ANGLE'][q]) - 90))* -1))
    Point_coords.append((next_x, next_y))
    q = q + 1
  elif (Measurepoints['FROM_POINT'][q]) == (Fixpoints['ID'][5]):
    next_x = (Fix_coords[6][0]) + ((Fixpoints['DISTANCE'][q]) * (cos(radians((Fixpoints['ANGLE'][q]) - 90))* -1))
    next_y = (Fix_coords[6][1]) + ((Fixpoints['DISTANCE'][q]) * (sin(radians((Fixpoints['ANGLE'][q]) - 90))* -1))
    Point_coords.append((next_x, next_y))
    q = q + 1
  elif (Measurepoints['FROM_POINT'][q]) == (Fixpoints['ID'][6]):
    next_x = (Fix_coords[7][0]) + ((Fixpoints['DISTANCE'][q]) * (cos(radians((Fixpoints['ANGLE'][q]) - 90))* -1))
    next_y = (Fix_coords[7][1]) + ((Fixpoints['DISTANCE'][q]) * (sin(radians((Fixpoints['ANGLE'][q]) - 90))* -1))
    Point_coords.append((next_x, next_y))
    q = q + 1
  elif (Measurepoints['FROM_POINT'][q]) == (Fixpoints['ID'][7]):
    next_x = (Fix_coords[8][0]) + ((Fixpoints['DISTANCE'][q]) * (cos(radians((Fixpoints['ANGLE'][q]) - 90))* -1))
    next_y = (Fix_coords[8][1]) + ((Fixpoints['DISTANCE'][q]) * (sin(radians((Fixpoints['ANGLE'][q]) - 90))* -1))
    Point_coords.append((next_x, next_y))
    q = q + 1
  elif (Measurepoints['FROM_POINT'][q]) == (Fixpoints['ID'][8]):
    next_x = (Fix_coords[9][0]) + ((Fixpoints['DISTANCE'][q]) * (cos(radians((Fixpoints['ANGLE'][q]) - 90))* -1))
    next_y = (Fix_coords[9][1]) + ((Fixpoints['DISTANCE'][q]) * (sin(radians((Fixpoints['ANGLE'][q]) - 90))* -1))
    Point_coords.append((next_x, next_y))
    q = q + 1
  elif (Measurepoints['FROM_POINT'][q]) == (Fixpoints['ID'][9]):
    next_x = (Fix_coords[10][0]) + ((Fixpoints['DISTANCE'][q]) * (cos(radians((Fixpoints['ANGLE'][q]) - 90))* -1))
    next_y = (Fix_coords[10][1]) + ((Fixpoints['DISTANCE'][q]) * (sin(radians((Fixpoints['ANGLE'][q]) - 90))* -1))
    Point_coords.append((next_x, next_y))
  elif (Measurepoints['FROM_POINT'][q]) == (Fixpoints['ID'][10]):
    next_x = (Fix_coords[11][0]) + ((Fixpoints['DISTANCE'][q]) * (cos(radians((Fixpoints['ANGLE'][q]) - 90))* -1))
    next_y = (Fix_coords[11][1]) + ((Fixpoints['DISTANCE'][q]) * (sin(radians((Fixpoints['ANGLE'][q]) - 90))* -1))
    Point_coords.append((next_x, next_y))
    q = q + 1
  elif (Measurepoints['FROM_POINT'][q]) == (Fixpoints['ID'][11]):
    next_x = (Fix_coords[12][0]) + ((Fixpoints['DISTANCE'][q]) * (cos(radians((Fixpoints['ANGLE'][q]) - 90))* -1))
    next_y = (Fix_coords[12][1]) + ((Fixpoints['DISTANCE'][q]) * (sin(radians((Fixpoints['ANGLE'][q]) - 90))* -1))
    Point_coords.append((next_x, next_y))
    q = q + 1

plt.plot(*zip(*Point_coords))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2890             try:
# -> 2891                 return self._engine.get_loc(casted_key)
#    2892             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 11
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1-91726839b4cc> in <module>()
#      70     q = q + 1
# ...
